# %% [markdown]
# # Importing Libraries

# %%
# importing libraries
import os
import sys
import os.path
import cv2
import matplotlib.pyplot as plt
from shutil import copy2

# %% [markdown]
# # Global Variables for Setting I/O Directories

# %%
#Global Variables

#############################################MODIFIYABLE################################################
IMAGE_FOLDER_PATH = "D:\\Full Food Dataset"                 #set this to current dataset path

IMAGE_TEMP_PATH = "D:\\Full Food Dataset\\Temp\\"

OUTPUT_LARGE_PATH_FOOD = "D:\\Food Datasets\\Large Training Dataset\\Food\\"       #set this to desired output path
OUTPUT_LARGE_PATH_NO_FOOD = "D:\\Food Datasets\\Large Training Dataset\\Non Food\\"    #set this to desired output path

OUTPUT_SMALL_PATH_FOOD = "D:\\Food Datasets\\Small Training Dataset\\Food\\"       #set this to desired output path
OUTPUT_SMALL_PATH_NO_FOOD = "D:\\Food Datasets\\Small Training Dataset\\Non Food\\"    #set this to desired output path

OUTPUT_MAIN_PATH_FOOD = "D:\\Food Datasets\\Full Training Dataset\\Food\\"       #set this to desired output path
OUTPUT_MAIN_PATH_NO_FOOD = "D:\\Food Datasets\\Full Training Dataset\\Non Food\\"    #set this to desired output path

OUTPUT_TINY_PATH_FOOD = "D:\\Food Datasets\\Tiny Training Dataset\\Food\\"       #set this to desired output path
OUTPUT_TINY_PATH_NO_FOOD = "D:\\Food Datasets\\Tiny Training Dataset\\Non Food\\"    #set this to desired output path

OUTPUT_VERY_TINY_PATH_FOOD = "D:\\Food Datasets\\Very Tiny Training Dataset\\Food\\"       #set this to desired output path
OUTPUT_VERY_TINY_PATH_NO_FOOD = "D:\\Food Datasets\\Very Tiny Training Dataset\\Non Food\\"    #set this to desired output path

OUTPUT_BALANCED_PATH_FOOD = "D:\\Food Datasets\\Balanced Training Dataset\\Food\\"       #set this to desired output path
OUTPUT_BALANCED_PATH_NO_FOOD = "D:\\Food Datasets\\Balanced Training Dataset\\Non Food\\"    #set this to desired output path

Google_Limit = 1000000         #set this to limit the number of images from google (1000000 is no limit)
Bing_Limit = 1000000           #set this to limit the number of images from bing (1000000 is no limit)
General_Limit = 0              #this sets the genetal limit (unused)
Google_Limit_Very_Tiny = 1000
Bing_Limit_Very_Tiny = 1000
Google_Limit_Tiny = 2000
Bing_Limit_Tiny = 1000
Google_Limit_Small = 5000
Bing_Limit_Small = 2500
Google_Limit_Balanced = 15000
Bing_Limit_Balanced = 5000
Google_Limit_Large = 30000
Bing_Limit_Large = 5000
########################################################################################################

############################################CONSTANTS###################################################
FOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_MAIN_PATH_FOOD + "G-256p\\"
FOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_MAIN_PATH_FOOD + "G-360p\\"
FOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_MAIN_PATH_FOOD + "G-480p\\"
FOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_MAIN_PATH_FOOD + "G-640p\\"
FOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_MAIN_PATH_FOOD + "G-720p\\"
FOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_MAIN_PATH_FOOD + "G-1024p\\"
FOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_MAIN_PATH_FOOD + "G-1080p\\"
FOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_MAIN_PATH_FOOD + "G-Medium\\"
FOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_MAIN_PATH_FOOD + "G-Large\\"

NOFOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_MAIN_PATH_NO_FOOD + "G-256p\\"
NOFOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_MAIN_PATH_NO_FOOD + "G-360p\\"
NOFOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_MAIN_PATH_NO_FOOD + "G-480p\\"
NOFOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_MAIN_PATH_NO_FOOD + "G-640p\\"
NOFOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_MAIN_PATH_NO_FOOD + "G-720p\\"
NOFOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_MAIN_PATH_NO_FOOD + "G-1024p\\"
NOFOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_MAIN_PATH_NO_FOOD + "G-1080p\\"
NOFOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_MAIN_PATH_NO_FOOD + "G-Medium\\"
NOFOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_MAIN_PATH_NO_FOOD + "G-Large\\"

FOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_MAIN_PATH_FOOD + "B-Small\\"
FOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_MAIN_PATH_FOOD + "B-640p\\"
FOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_MAIN_PATH_FOOD + "B-1000p\\"
FOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_MAIN_PATH_FOOD + "B-Medium\\"
FOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_MAIN_PATH_FOOD + "B-Large\\"
FOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_MAIN_PATH_FOOD + "B-1280p\\"
FOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_MAIN_PATH_FOOD + "B-1920p\\"

NOFOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_MAIN_PATH_NO_FOOD + "B-Small\\"
NOFOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_MAIN_PATH_NO_FOOD + "B-640p\\"
NOFOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_MAIN_PATH_NO_FOOD + "B-1000p\\"
NOFOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_MAIN_PATH_NO_FOOD + "B-Medium\\"
NOFOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_MAIN_PATH_NO_FOOD + "B-Large\\"
NOFOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_MAIN_PATH_NO_FOOD + "B-1280p\\"
NOFOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_MAIN_PATH_NO_FOOD + "B-1920p\\"
########################################################################################################
SMALL_FOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_SMALL_PATH_FOOD + "G-256p\\"
SMALL_FOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_SMALL_PATH_FOOD + "G-360p\\"
SMALL_FOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_SMALL_PATH_FOOD + "G-480p\\"
SMALL_FOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_SMALL_PATH_FOOD + "G-640p\\"
SMALL_FOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_SMALL_PATH_FOOD + "G-720p\\"
SMALL_FOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_SMALL_PATH_FOOD + "G-1024p\\"
SMALL_FOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_SMALL_PATH_FOOD + "G-1080p\\"
SMALL_FOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_SMALL_PATH_FOOD + "G-Medium\\"
SMALL_FOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_SMALL_PATH_FOOD + "G-Large\\"

SMALL_NOFOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_SMALL_PATH_NO_FOOD + "G-256p\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_SMALL_PATH_NO_FOOD + "G-360p\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_SMALL_PATH_NO_FOOD + "G-480p\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_SMALL_PATH_NO_FOOD + "G-640p\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_SMALL_PATH_NO_FOOD + "G-720p\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_SMALL_PATH_NO_FOOD + "G-1024p\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_SMALL_PATH_NO_FOOD + "G-1080p\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_SMALL_PATH_NO_FOOD + "G-Medium\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_SMALL_PATH_NO_FOOD + "G-Large\\"

SMALL_FOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_SMALL_PATH_FOOD + "B-Small\\"
SMALL_FOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_SMALL_PATH_FOOD + "B-640p\\"
SMALL_FOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_SMALL_PATH_FOOD + "B-1000p\\"
SMALL_FOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_SMALL_PATH_FOOD + "B-Medium\\"
SMALL_FOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_SMALL_PATH_FOOD + "B-Large\\"
SMALL_FOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_SMALL_PATH_FOOD + "B-1280p\\"
SMALL_FOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_SMALL_PATH_FOOD + "B-1920p\\"

SMALL_NOFOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_SMALL_PATH_NO_FOOD + "B-Small\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_SMALL_PATH_NO_FOOD + "B-640p\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_SMALL_PATH_NO_FOOD + "B-1000p\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_SMALL_PATH_NO_FOOD + "B-Medium\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_SMALL_PATH_NO_FOOD + "B-Large\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_SMALL_PATH_NO_FOOD + "B-1280p\\"
SMALL_NOFOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_SMALL_PATH_NO_FOOD + "B-1920p\\"
########################################################################################################
TINY_FOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_TINY_PATH_FOOD + "G-256p\\"
TINY_FOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_TINY_PATH_FOOD + "G-360p\\"
TINY_FOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_TINY_PATH_FOOD + "G-480p\\"
TINY_FOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_TINY_PATH_FOOD + "G-640p\\"
TINY_FOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_TINY_PATH_FOOD + "G-720p\\"
TINY_FOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_TINY_PATH_FOOD + "G-1024p\\"
TINY_FOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_TINY_PATH_FOOD + "G-1080p\\"
TINY_FOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_TINY_PATH_FOOD + "G-Medium\\"
TINY_FOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_TINY_PATH_FOOD + "G-Large\\"

TINY_NOFOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_TINY_PATH_NO_FOOD + "G-256p\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_TINY_PATH_NO_FOOD + "G-360p\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_TINY_PATH_NO_FOOD + "G-480p\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_TINY_PATH_NO_FOOD + "G-640p\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_TINY_PATH_NO_FOOD + "G-720p\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_TINY_PATH_NO_FOOD + "G-1024p\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_TINY_PATH_NO_FOOD + "G-1080p\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_TINY_PATH_NO_FOOD + "G-Medium\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_TINY_PATH_NO_FOOD + "G-Large\\"

TINY_FOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_TINY_PATH_FOOD + "B-Small\\"
TINY_FOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_TINY_PATH_FOOD + "B-640p\\"
TINY_FOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_TINY_PATH_FOOD + "B-1000p\\"
TINY_FOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_TINY_PATH_FOOD + "B-Medium\\"
TINY_FOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_TINY_PATH_FOOD + "B-Large\\"
TINY_FOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_TINY_PATH_FOOD + "B-1280p\\"
TINY_FOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_TINY_PATH_FOOD + "B-1920p\\"

TINY_NOFOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_TINY_PATH_NO_FOOD + "B-Small\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_TINY_PATH_NO_FOOD + "B-640p\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_TINY_PATH_NO_FOOD + "B-1000p\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_TINY_PATH_NO_FOOD + "B-Medium\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_TINY_PATH_NO_FOOD + "B-Large\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_TINY_PATH_NO_FOOD + "B-1280p\\"
TINY_NOFOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_TINY_PATH_NO_FOOD + "B-1920p\\"
########################################################################################################
LARGE_FOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_LARGE_PATH_FOOD + "G-256p\\"
LARGE_FOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_LARGE_PATH_FOOD + "G-360p\\"
LARGE_FOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_LARGE_PATH_FOOD + "G-480p\\"
LARGE_FOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_LARGE_PATH_FOOD + "G-640p\\"
LARGE_FOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_LARGE_PATH_FOOD + "G-720p\\"
LARGE_FOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_LARGE_PATH_FOOD + "G-1024p\\"
LARGE_FOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_LARGE_PATH_FOOD + "G-1080p\\"
LARGE_FOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_LARGE_PATH_FOOD + "G-Medium\\"
LARGE_FOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_LARGE_PATH_FOOD + "G-Large\\"

LARGE_NOFOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_LARGE_PATH_NO_FOOD + "G-256p\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_LARGE_PATH_NO_FOOD + "G-360p\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_LARGE_PATH_NO_FOOD + "G-480p\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_LARGE_PATH_NO_FOOD + "G-640p\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_LARGE_PATH_NO_FOOD + "G-720p\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_LARGE_PATH_NO_FOOD + "G-1024p\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_LARGE_PATH_NO_FOOD + "G-1080p\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_LARGE_PATH_NO_FOOD + "G-Medium\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_LARGE_PATH_NO_FOOD + "G-Large\\"

LARGE_FOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_LARGE_PATH_FOOD + "B-Small\\"
LARGE_FOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_LARGE_PATH_FOOD + "B-640p\\"
LARGE_FOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_LARGE_PATH_FOOD + "B-1000p\\"
LARGE_FOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_LARGE_PATH_FOOD + "B-Medium\\"
LARGE_FOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_LARGE_PATH_FOOD + "B-Large\\"
LARGE_FOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_LARGE_PATH_FOOD + "B-1280p\\"
LARGE_FOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_LARGE_PATH_FOOD + "B-1920p\\"

LARGE_NOFOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_LARGE_PATH_NO_FOOD + "B-Small\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_LARGE_PATH_NO_FOOD + "B-640p\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_LARGE_PATH_NO_FOOD + "B-1000p\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_LARGE_PATH_NO_FOOD + "B-Medium\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_LARGE_PATH_NO_FOOD + "B-Large\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_LARGE_PATH_NO_FOOD + "B-1280p\\"
LARGE_NOFOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_LARGE_PATH_NO_FOOD + "B-1920p\\"
########################################################################################################
VERY_TINY_FOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_VERY_TINY_PATH_FOOD + "G-256p\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_VERY_TINY_PATH_FOOD + "G-360p\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_VERY_TINY_PATH_FOOD + "G-480p\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_VERY_TINY_PATH_FOOD + "G-640p\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_VERY_TINY_PATH_FOOD + "G-720p\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_VERY_TINY_PATH_FOOD + "G-1024p\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_VERY_TINY_PATH_FOOD + "G-1080p\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_VERY_TINY_PATH_FOOD + "G-Medium\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_VERY_TINY_PATH_FOOD + "G-Large\\"

VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "G-256p\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "G-360p\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "G-480p\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "G-640p\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "G-720p\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "G-1024p\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "G-1080p\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_VERY_TINY_PATH_NO_FOOD + "G-Medium\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_VERY_TINY_PATH_NO_FOOD + "G-Large\\"

VERY_TINY_FOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_VERY_TINY_PATH_FOOD + "B-Small\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_VERY_TINY_PATH_FOOD + "B-640p\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_VERY_TINY_PATH_FOOD + "B-1000p\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_VERY_TINY_PATH_FOOD + "B-Medium\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_VERY_TINY_PATH_FOOD + "B-Large\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_VERY_TINY_PATH_FOOD + "B-1280p\\"
VERY_TINY_FOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_VERY_TINY_PATH_FOOD + "B-1920p\\"

VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_VERY_TINY_PATH_NO_FOOD + "B-Small\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "B-640p\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "B-1000p\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_VERY_TINY_PATH_NO_FOOD + "B-Medium\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_VERY_TINY_PATH_NO_FOOD + "B-Large\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "B-1280p\\"
VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_VERY_TINY_PATH_NO_FOOD + "B-1920p\\"
########################################################################################################
BALANCED_FOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_BALANCED_PATH_FOOD + "G-256p\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_BALANCED_PATH_FOOD + "G-360p\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_BALANCED_PATH_FOOD + "G-480p\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_BALANCED_PATH_FOOD + "G-640p\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_BALANCED_PATH_FOOD + "G-720p\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_BALANCED_PATH_FOOD + "G-1024p\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_BALANCED_PATH_FOOD + "G-1080p\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_BALANCED_PATH_FOOD + "G-Medium\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_BALANCED_PATH_FOOD + "G-Large\\"

BALANCED_NOFOOD_OUTPUT_DIRECTORY_G256p = OUTPUT_BALANCED_PATH_NO_FOOD + "G-256p\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_G360p = OUTPUT_BALANCED_PATH_NO_FOOD + "G-360p\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_G480p = OUTPUT_BALANCED_PATH_NO_FOOD + "G-480p\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_G640p = OUTPUT_BALANCED_PATH_NO_FOOD + "G-640p\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_G720p = OUTPUT_BALANCED_PATH_NO_FOOD + "G-720p\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_G1024p = OUTPUT_BALANCED_PATH_NO_FOOD + "G-1024p\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_G1080p = OUTPUT_BALANCED_PATH_NO_FOOD + "G-1080p\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_GMedium = OUTPUT_BALANCED_PATH_NO_FOOD + "G-Medium\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_GLarge = OUTPUT_BALANCED_PATH_NO_FOOD + "G-Large\\"

BALANCED_FOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_BALANCED_PATH_FOOD + "B-Small\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_BALANCED_PATH_FOOD + "B-640p\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_BALANCED_PATH_FOOD + "B-1000p\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_BALANCED_PATH_FOOD + "B-Medium\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_BALANCED_PATH_FOOD + "B-Large\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_BALANCED_PATH_FOOD + "B-1280p\\"
BALANCED_FOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_BALANCED_PATH_FOOD + "B-1920p\\"

BALANCED_NOFOOD_OUTPUT_DIRECTORY_BSmall = OUTPUT_BALANCED_PATH_NO_FOOD + "B-Small\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_B640p = OUTPUT_BALANCED_PATH_NO_FOOD + "B-640p\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_B1000p = OUTPUT_BALANCED_PATH_NO_FOOD + "B-1000p\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_BMedium = OUTPUT_BALANCED_PATH_NO_FOOD + "B-Medium\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_BLarge = OUTPUT_BALANCED_PATH_NO_FOOD + "B-Large\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_B1280p = OUTPUT_BALANCED_PATH_NO_FOOD + "B-1280p\\"
BALANCED_NOFOOD_OUTPUT_DIRECTORY_B1920p = OUTPUT_BALANCED_PATH_NO_FOOD + "B-1920p\\"
########################################################################################################

# %% [markdown]
# # Global Variables for Filters and Queries Sets

# %%
# list of Google filters
#for food crawling
filters_none = []
filters_256 = []
filters_360 = []
filters_480 = []
filters_640 = []
filters_720 = []
filters_1000 = [] #medium
filters_1024 = []
filters_1080 = []
filters_1280 = [] #large

#for non food crawling
filters_none_nf = []
filters_256_nf = []
filters_360_nf = []
filters_480_nf = []
filters_640_nf = []
filters_720_nf = []
filters_1000_nf = [] #medium
filters_1024_nf = []
filters_1080_nf = []
filters_1280_nf = [] #large

# no filters
filters_none.append(None)
filters_none_nf.append(None)

#filters for RGB, date, size
filters_2016_256 = dict(size="=256x256", color="color", date=((2010, 1, 1), (2015, 12, 30)))
filters_2018_256 = dict(size="=256x256", color="color", date=((2016, 1, 1), (2018, 12, 30)))

filters_2016_360 = dict(size="=480x360", color="color", date=((2010, 1, 1), (2015, 12, 30)))
filters_2018_360 = dict(size="=480x360", color="color", date=((2016, 1, 1), (2018, 12, 30)))

filters_2016_480 = dict(size="=640x480", color="color", date=((2010, 1, 1), (2015, 12, 30)))
filters_2018_480 = dict(size="=640x480", color="color", date=((2016, 1, 1), (2018, 12, 30)))

filters_2016_640 = dict(size=">640x480", color="color", date=((2010, 1, 1), (2015, 12, 30)))
filters_2018_640 = dict(size=">640x480", color="color", date=((2016, 1, 1), (2018, 12, 30)))

filters_2016_720 = dict(size="=1280x720", color="color", date=((2010, 1, 1), (2015, 12, 30)))
filters_2018_720 = dict(size="=1280x720", color="color", date=((2016, 1, 1), (2018, 12, 30)))

filters_2016_1000 = dict(size="medium", color="color", date=((2010, 1, 1), (2015, 12, 30)))
filters_2018_1000 = dict(size="medium", color="color", date=((2016, 1, 1), (2018, 12, 30)))

filters_2016_1024 = dict(size="=1024x768", color="color", date=((2010, 1, 1), (2015, 12, 30)))
filters_2018_1024 = dict(size="=1024x768", color="color", date=((2016, 1, 1), (2018, 12, 30)))

filters_2016_1080 = dict(size="=1920x1080", color="color", date=((2010, 1, 1), (2015, 12, 30)))
filters_2018_1080 = dict(size="=1920x1080", color="color", date=((2016, 1, 1), (2018, 12, 30)))

filters_2016_1280 = dict(size="large", color="color", date=((2010, 1, 1), (2015, 12, 30)))
filters_2018_1280 = dict(size="large", color="color", date=((2016, 1, 1), (2018, 12, 30)))

#filters for size only
filters_256p = dict(size="=256x256", color="color")
filters_360p = dict(size="=480x360", color="color")
filters_480p = dict(size="=640x480", color="color")
filters_640p = dict(size=">640x480", color="color")
filters_720p = dict(size="=1280x720", color="color")
filters_1000p = dict(size="medium", color="color")
filters_1024p = dict(size="=1024x768", color="color")
filters_1080p = dict(size="=1920x1080", color="color")
filters_1280p = dict(size="large", color="color")

#filters for liscensing
filters_l1_256 = dict(size="=256x256", color="color", license="noncommercial")
filters_l2_256 = dict(size="=256x256", color="color", license="commercial")
filters_l3_256 = dict(size="=256x256", color="color", license="noncommercial,modify")
filters_l4_256 = dict(size="=256x256", color="color", license="commercial,modify")

filters_l1_360 = dict(size="=480x360", color="color", license="noncommercial")
filters_l2_360 = dict(size="=480x360", color="color", license="commercial")
filters_l3_360 = dict(size="=480x360", color="color", license="noncommercial,modify")
filters_l4_360 = dict(size="=480x360", color="color", license="commercial,modify")

filters_l1_480 = dict(size="=640x480", color="color", license="noncommercial")
filters_l2_480 = dict(size="=640x480", color="color", license="commercial")
filters_l3_480 = dict(size="=640x480", color="color", license="noncommercial,modify")
filters_l4_480 = dict(size="=640x480", color="color", license="commercial,modify")

filters_l1_640 = dict(size=">640x480", color="color", license="noncommercial")
filters_l2_640 = dict(size=">640x480", color="color", license="commercial")
filters_l3_640 = dict(size=">640x480", color="color", license="noncommercial,modify")
filters_l4_640 = dict(size=">640x480", color="color", license="commercial,modify")

filters_l1_720 = dict(size="=1280x720", color="color", license="noncommercial")
filters_l2_720 = dict(size="=1280x720", color="color", license="commercial")
filters_l3_720 = dict(size="=1280x720", color="color", license="noncommercial,modify")
filters_l4_720 = dict(size="=1280x720", color="color", license="commercial,modify")

filters_l1_1000 = dict(size="medium", color="color", license="noncommercial")
filters_l2_1000 = dict(size="medium", color="color", license="commercial")
filters_l3_1000 = dict(size="medium", color="color", license="noncommercial,modify")
filters_l4_1000 = dict(size="medium", color="color", license="commercial,modify")

filters_l1_1024 = dict(size="=1024x768", color="color", license="noncommercial")
filters_l2_1024 = dict(size="=1024x768", color="color", license="commercial")
filters_l3_1024 = dict(size="=1024x768", color="color", license="noncommercial,modify")
filters_l4_1024 = dict(size="=1024x768", color="color", license="commercial,modify")

filters_l1_1080 = dict(size="=1920x1080", color="color", license="noncommercial")
filters_l2_1080 = dict(size="=1920x1080", color="color", license="commercial")
filters_l3_1080 = dict(size="=1920x1080", color="color", license="noncommercial,modify")
filters_l4_1080 = dict(size="=1920x1080", color="color", license="commercial,modify")

filters_l1_1280 = dict(size="large", color="color", license="noncommercial")
filters_l2_1280 = dict(size="large", color="color", license="commercial")
filters_l3_1280 = dict(size="large", color="color", license="noncommercial,modify")
filters_l4_1280 = dict(size="large", color="color", license="commercial,modify")

#food filter sets
filters_256.append(filters_256p)
#filters_256.append(filters_l1_256)
#filters_256.append(filters_l2_256)
#filters_256.append(filters_l3_256)
#filters_256.append(filters_l4_256)

filters_360.append(filters_360p)
#filters_360.append(filters_l1_360)
#filters_360.append(filters_l2_360)
#filters_360.append(filters_l3_360)
#filters_360.append(filters_l4_360)

filters_480.append(filters_480p)
filters_480.append(filters_2016_480)
filters_480.append(filters_2018_480)
#filters_480.append(filters_l1_480)
#filters_480.append(filters_l2_480)
#filters_480.append(filters_l3_480)
#filters_480.append(filters_l4_480)

filters_640.append(filters_640p)
#filters_640.append(filters_l1_640)
#filters_640.append(filters_l2_640)
#filters_640.append(filters_l3_640)
#filters_640.append(filters_l4_640)

filters_720.append(filters_720p)
filters_720.append(filters_2016_720)
filters_720.append(filters_2018_720)
#filters_720.append(filters_l1_720)
#filters_720.append(filters_l2_720)
#filters_720.append(filters_l3_720)
#filters_720.append(filters_l4_720)

filters_1000.append(filters_1000p)
#filters_1000.append(filters_l1_1000)
#filters_1000.append(filters_l2_1000)
#filters_1000.append(filters_l3_1000)
#filters_1000.append(filters_l4_1000)

filters_1024.append(filters_1024p)
filters_1024.append(filters_2016_1024)
filters_1024.append(filters_2018_1024)
#filters_1024.append(filters_l1_1024)
#filters_1024.append(filters_l2_1024)
#filters_1024.append(filters_l3_1024)
#filters_1024.append(filters_l4_1024)

filters_1080.append(filters_1080p)
filters_1080.append(filters_2016_1080)
filters_1080.append(filters_2018_1080)
#filters_1080.append(filters_l1_1080)
#filters_1080.append(filters_l2_1080)
#filters_1080.append(filters_l3_1080)
#filters_1080.append(filters_l4_1080)

filters_1280.append(filters_1280p)
filters_1280.append(filters_l1_1280)
filters_1280.append(filters_l2_1280)
filters_1280.append(filters_l3_1280)
filters_1280.append(filters_l4_1280)

# non food filter sets
filters_256_nf.append(filters_256p)

filters_360_nf.append(filters_360p)

filters_480_nf.append(filters_480p)

filters_640_nf.append(filters_640p)

filters_720_nf.append(filters_720p)

filters_1000_nf.append(filters_1000p)

filters_1024_nf.append(filters_1024p)

filters_1080_nf.append(filters_1080p)

filters_1280_nf.append(filters_1280p)

# list of Bing filters
#for food crawling
Bingfilters_none = []
Bingfilters_480 = [] #small
Bingfilters_640 = []
Bingfilters_1000 = []
Bingfilters_1024 = [] #medium
Bingfilters_1080 = [] #large
Bingfilters_1280 = []
Bingfilters_1920 = []

#for non food crawling
Bingfilters_none_nf = []
Bingfilters_480_nf = [] #small
Bingfilters_640_nf = []
Bingfilters_1000_nf = []
Bingfilters_1024_nf = [] #medium
Bingfilters_1080_nf = [] #large
Bingfilters_1280_nf = []
Bingfilters_1920_nf = []

# no filters
Bingfilters_none.append(None)
Bingfilters_none_nf.append(None)

#filters for RGB, date, size, liscence
filters_pastyear_480 = dict(size="small", color="color", date="pastyear")
filters_nodate_480 = dict(size="small", color="color")
filters_li1_480 = dict(size="small", color="color", license="noncommercial")
filters_li2_480 = dict(size="small", color="color", license="commercial")
filters_li3_480 = dict(size="small", color="color", license="noncommercial,modify")
filters_li4_480 = dict(size="small", color="color", license="commercial,modify")
filters_li5_480 = dict(size="small", color="color", license="creativecommons")
filters_li6_480 = dict(size="small", color="color", license="publicdomain")

filters_pastyear_640 = dict(size=">640x480", color="color", date="pastyear")
filters_nodate_640 = dict(size=">640x480", color="color")
filters_li1_640 = dict(size=">640x480", color="color", license="noncommercial")
filters_li2_640 = dict(size=">640x480", color="color", license="commercial")
filters_li3_640 = dict(size=">640x480", color="color", license="noncommercial,modify")
filters_li4_640 = dict(size=">640x480", color="color", license="commercial,modify")
filters_li5_640 = dict(size=">640x480", color="color", license="creativecommons")
filters_li6_640 = dict(size=">640x480", color="color", license="publicdomain")

filters_pastyear_1000 = dict(size=">1000x1000", color="color", date="pastyear")
filters_nodate_1000 = dict(size=">1000x1000", color="color")
filters_li1_1000 = dict(size=">1000x1000", color="color", license="noncommercial")
filters_li2_1000 = dict(size=">1000x1000", color="color", license="commercial")
filters_li3_1000 = dict(size=">1000x1000", color="color", license="noncommercial,modify")
filters_li4_1000 = dict(size=">1000x1000", color="color", license="commercial,modify")
filters_li5_1000 = dict(size=">1000x1000", color="color", license="creativecommons")
filters_li6_1000 = dict(size=">1000x1000", color="color", license="publicdomain")

filters_pastyear_1024 = dict(size="medium", color="color", date="pastyear")
filters_nodate_1024 = dict(size="medium", color="color")
filters_li1_1024 = dict(size="medium", color="color", license="noncommercial")
filters_li2_1024 = dict(size="medium", color="color", license="commercial")
filters_li3_1024 = dict(size="medium", color="color", license="noncommercial,modify")
filters_li4_1024 = dict(size="medium", color="color", license="commercial,modify")
filters_li5_1024 = dict(size="medium", color="color", license="creativecommons")
filters_li6_1024 = dict(size="medium", color="color", license="publicdomain")

filters_pastyear_1080 = dict(size="large", color="color", date="pastyear")
filters_nodate_1080 = dict(size="large", color="color")
filters_li1_1080 = dict(size="large", color="color", license="noncommercial")
filters_li2_1080 = dict(size="large", color="color", license="commercial")
filters_li3_1080 = dict(size="large", color="color", license="noncommercial,modify")
filters_li4_1080 = dict(size="large", color="color", license="commercial,modify")
filters_li5_1080 = dict(size="large", color="color", license="creativecommons")
filters_li6_1080 = dict(size="large", color="color", license="publicdomain")

filters_pastyear_1280 = dict(size=">1280x720", color="color", date="pastyear")
filters_nodate_1280 = dict(size=">1280x720", color="color")
filters_li1_1280 = dict(size=">1280x720", color="color", license="noncommercial")
filters_li2_1280 = dict(size=">1280x720", color="color", license="commercial")
filters_li3_1280 = dict(size=">1280x720", color="color", license="noncommercial,modify")
filters_li4_1280 = dict(size=">1280x720", color="color", license="commercial,modify")
filters_li5_1280 = dict(size=">1280x720", color="color", license="creativecommons")
filters_li6_1280 = dict(size=">1280x720", color="color", license="publicdomain")

filters_pastyear_1920= dict(size=">1920x1080", color="color", date="pastyear")
filters_nodate_1920 = dict(size=">1920x1080", color="color")
filters_li1_1920 = dict(size=">1920x1080", color="color", license="noncommercial")
filters_li2_1920 = dict(size=">1920x1080", color="color", license="commercial")
filters_li3_1920 = dict(size=">1920x1080", color="color", license="noncommercial,modify")
filters_li4_1920 = dict(size=">1920x1080", color="color", license="commercial,modify")
filters_li5_1920 = dict(size=">1920x1080", color="color", license="creativecommons")
filters_li6_1920 = dict(size=">1920x1080", color="color", license="publicdomain")

#food filter sets
Bingfilters_480.append(filters_nodate_480)
Bingfilters_480.append(filters_li5_480)
Bingfilters_480.append(filters_li6_480)

Bingfilters_640.append(filters_nodate_640)
Bingfilters_640.append(filters_li5_640)
Bingfilters_640.append(filters_li6_640)

Bingfilters_1000.append(filters_nodate_1000)
Bingfilters_1000.append(filters_li5_1000)
Bingfilters_1000.append(filters_li6_1000)

Bingfilters_1024.append(filters_nodate_1024)
Bingfilters_1024.append(filters_li5_1024)
Bingfilters_1024.append(filters_li6_1024)

Bingfilters_1080.append(filters_nodate_1080)
Bingfilters_1080.append(filters_li5_1080)
Bingfilters_1080.append(filters_li6_1080)

Bingfilters_1280.append(filters_nodate_1280)
Bingfilters_1280.append(filters_li5_1280)
Bingfilters_1280.append(filters_li6_1280)

Bingfilters_1920.append(filters_nodate_1920)
Bingfilters_1920.append(filters_li5_1920)
Bingfilters_1920.append(filters_li6_1920)

# non food filter sets
Bingfilters_480_nf.append(filters_nodate_480)
Bingfilters_640_nf.append(filters_nodate_640)
Bingfilters_1000_nf.append(filters_nodate_1000)
Bingfilters_1024_nf.append(filters_nodate_1024)
Bingfilters_1080_nf.append(filters_nodate_1080)
Bingfilters_1280_nf.append(filters_nodate_1280)
Bingfilters_1920_nf.append(filters_nodate_1920)

# Google filters Names
filterNamesExtended = []
filterNamesExtended_nf = []
filterNamesExtended.append('all time')
filterNamesExtended.append('2010-2016')
filterNamesExtended.append('2017-2018')
#filterNamesExtended.append('noncommercial')
#filterNamesExtended.append('commercial')
#filterNamesExtended.append('noncommercial modified')
#filterNamesExtended.append('commercial modified')
filterNamesExtended_nf.append('all time')

filterNames = []
filterNames_nf = []
filterNames.append('all time')
#filterNames.append('noncommercial')
#filterNames.append('commercial')
#filterNames.append('noncommercial modified')
#filterNames.append('commercial modified')
filterNames_nf.append('all time')

# Bing filters Names
BingfilterNames = []
BingfilterNames_nf = []

BingfilterNames.append('all time')
BingfilterNames.append('creativecommons')
BingfilterNames.append('publicdomain')
BingfilterNames_nf.append('all time')


#list of Search Queries
queries = []
#tunisian
queries.append('tunisian food')
queries.append('tunisian food popular')
queries.append('traditional tunisian food')
queries.append('tunisian cuisine')
queries.append('arabic food')
queries.append('real scenario tunisian food images')
queries.append('people eating tunisian food')
queries.append('people in tunisian restaurant')
queries.append('very far images tunisian food')
queries.append('eating tunisian')
queries.append('best tunisian restaurants')
#lebanese
queries.append('lebanese food')
queries.append('lebanese food popular')
queries.append('traditional lebanese food')
queries.append('lebanese cuisine')
queries.append('real scenario lebanese food images')
queries.append('people eating lebanese food')
queries.append('people in lebanese restaurant')
queries.append('very far images lebanese food')
queries.append('eating lebanese')
queries.append('best lebanese restaurants')
#eating
queries.append('food images low light')
queries.append('food ads')
queries.append('food billboards')
queries.append('food billboards lebanon')
queries.append('food billboards Tunisia')
queries.append('food transportation')
queries.append('food vehicules')
#queries.append('food transportation')
queries.append('food packages')
queries.append('food packaging')
queries.append('food menus')
queries.append('real scenario food images')
queries.append('people eating')
queries.append('supermarket')
queries.append('market')
queries.append('food market')
queries.append('real scenario images containing food')
queries.append('very far images food')
queries.append('eating')
#food
queries.append('pizza')
queries.append('burger')
queries.append('kitchen')
queries.append('water')
queries.append('water bottles')
queries.append('water galloons')
queries.append('refrigerator')
queries.append('vending machine')
queries.append('chocolat')
queries.append('candy')
queries.append('cream')
queries.append('juice bottles')
queries.append('biscuit')
queries.append('jello')
queries.append('custard')
queries.append('soft drinks')
queries.append('fries')
queries.append('potato')
queries.append('milk')
queries.append('croissant')
queries.append('marshmallow')
queries.append('nuts')
queries.append('popcorn')
queries.append('steak')
queries.append('chips')
queries.append('biscuit')
queries.append('cream')
queries.append('corn flakes')
queries.append('barbeque')
queries.append('hot dog')
queries.append('tartine')
queries.append('mortadella')
queries.append('mortadella sandwish')
queries.append('croissant')
queries.append('nutella')
#queries.append('chocomax')
queries.append('laban')
queries.append('labneh')
queries.append('cake')
#lebanese food
#queries.append('lebanese food')
#queries.append('lebanese food popular')
#queries.append('lebanese food lebanon')
#queries.append('lebanese food pinterest')
queries.append('lebanese cuisine')
queries.append('lebanese food images in restaurants')
queries.append('lebanese restaurants')
queries.append('lebanese food ads')
queries.append('lebanese food breakfast')
queries.append('lebanese food lunch')
queries.append('lebanese food dinner')
queries.append('lebanese food dessert')
queries.append('lebanese food fruits')
queries.append('lebanese food vegetables')
queries.append('lebanese cocktail')
queries.append('lebanese drinks')
queries.append('lebanese coffee')
queries.append('lebanese shisha')
queries.append('lebanese cigarettes')
queries.append('lebanese smoking')
queries.append('lebanese caffe')
queries.append('lebanese bakery')
queries.append('lebanese manakish')
queries.append('lebanese fast food')
queries.append('lebanese pizza')
queries.append('lebanese burger')
queries.append('lebanese sandwich')
queries.append('lebanese salad')
queries.append('lebanese ice cream')
queries.append('lebanese saj')
queries.append('lebanese seafood')
queries.append('lebanese kebab')
queries.append('lebanese steak')
queries.append('lebanese vegetarian food')
queries.append('lebanese tea')
queries.append('lebanese crepes')
queries.append('lebanese foul')
queries.append('lebanese juices')
queries.append('lebanese pub food')
queries.append('lebanese shawarma')
queries.append('lebanese falafel')
queries.append('lebanese oriental food')
queries.append('lebanese kaak')
queries.append('lebanese healthy food')
queries.append('lebanese sushi')
queries.append('lebanese food kiosks')
queries.append('lebanese bakeries')
queries.append('lebanese furn')
queries.append('lebanese food courts')
queries.append('lebanese pubs')
queries.append('lebanese food locations')
queries.append('lebanese kibbeh')
queries.append('lebanese hummus')
queries.append('lebanese tabouli')
queries.append('lebanese mujadara')
queries.append('lebanese homemade food')
queries.append('lebanese food pastry')
#Tunisian food
queries.append('tunisian food')
queries.append('tunisian food popular')
queries.append('tunisian food tunisia')
queries.append('tunisian food pinterest')
queries.append('tunisian cuisine')
queries.append('tunisian food images in restaurants')
queries.append('tunisian restaurants')
queries.append('tunisian food ads')
queries.append('tunisian food breakfast')
queries.append('tunisian food lunch')
queries.append('tunisian food dinner')
queries.append('tunisian food dessert')
queries.append('tunisian food fruits')
queries.append('tunisian food vegetables')
queries.append('tunisian cocktail')
queries.append('tunisian drinks')
queries.append('tunisian coffee')
queries.append('tunisian shisha')
queries.append('tunisian cigarettes')
queries.append('tunisian smoking')
queries.append('tunisian caffe')
queries.append('tunisian bakery')
queries.append('tunisian manakish')
queries.append('tunisian fast food')
queries.append('tunisian pizza')
queries.append('tunisian burger')
queries.append('tunisian sandwich')
queries.append('tunisian salad')
queries.append('tunisian ice cream')
queries.append('tunisian saj')
queries.append('tunisian seafood')
queries.append('tunisian kebab')
queries.append('tunisian steak')
queries.append('tunisian vegetarian food')
queries.append('tunisian tea')
queries.append('tunisian crepes')
queries.append('tunisian foul')
queries.append('tunisian juices')
queries.append('tunisian pub food')
queries.append('tunisian shawarma')
queries.append('tunisian falafel')
queries.append('tunisian oriental food')
queries.append('tunisian kaak')
queries.append('tunisian healthy food')
queries.append('tunisian sushi')
queries.append('tunisian food kiosks')
queries.append('tunisian bakeries')
queries.append('tunisian furn')
queries.append('tunisian food courts')
queries.append('tunisian pubs')
queries.append('tunisian food locations')
queries.append('tunisian kibbeh')
queries.append('tunisian hummus')
queries.append('tunisian tabouli')
queries.append('tunisian mujadara')
queries.append('tunisian homemade food')
queries.append('tunisian food pastry')
#lebanese restaurants
#queries.append('mcdonalds lebanon')
#queries.append('burger king lebanon')
#queries.append('kfc lebanon')
#queries.append('roadster diner lebanon')
#queries.append('zaatar w zeit lebanon')
#queries.append('tonino lebanon')
#queries.append('malak al tawouk lebanon')
#queries.append('hardees lebanon')
#queries.append('le sam lebanon')
queries.append('cafeteria lebanon')
queries.append('cafeteria')
queries.append('school catereia lebanon')
#queries.append('deek duke lebanon')
#queries.append('classic burger lebanon')
#queries.append('starbucks lebanon')
#queries.append('lody\'s lebanon')
#queries.append('al saniour lebanon')
#queries.append('go tango lebanon')
#queries.append('bliss house lebanon')
#queries.append('kb doner lebanon')
#queries.append('domino\'s pizza lebanon')
#queries.append('pizzahut lebanon')
#queries.append('wooden bakery lebanon')
#queries.append('breakfast to breakfast lebanon')
#queries.append('sea sweet lebanon')
#queries.append('dip and dip lebanon')
#queries.append('subway restaurant lebanon')
#tunisian restaurants
#queries.append('mcdonalds tunisia')
#queries.append('burger king tunisia')
#queries.append('kfc tunisia')
#queries.append('roadster diner tunisia')
#queries.append('zaatar w zeit tunisia')
#queries.append('hardees tunisia')
#queries.append('le sam tunisia')
queries.append('cafeteria tunisia')
queries.append('school cafeteria tunisia')
queries.append('school kiosks tunisia')
#queries.append('deek duke tunisia')
#queries.append('classic burger tunisia')
#queries.append('starbucks tunisia')
#queries.append('kb doner tunisia')
#queries.append('domino\'s pizza tunisia')
#queries.append('pizzahut tunisia')
#queries.append('dip and dip tunisia')
queries.append('Biscuits industriels')
queries.append('Cake industriel')
queries.append('Casse-croûte au Fromage')
queries.append('Céréales Grain d\'Or')
queries.append('Couscous agneau')
queries.append('Couscous poulet')
queries.append('Danette cream')
queries.append('Dinde grillée')
queries.append('Grilled turkey')
queries.append('Fromage fondu triangle')
queries.append('Spread cheese')
queries.append('Fruits')
queries.append('Industrial wafers')
queries.append('wafers')
queries.append('Jus frais')
queries.append('Fresh juice')
queries.append('Industrial juice')
queries.append('Lait')
queries.append('Légumes')
queries.append('Macaroni agneau')
queries.append('Macaroni poulet')
queries.append('spagetti')
queries.append('Nouacer poulet')
queries.append('oeuf frit')
queries.append('Fried egg')
queries.append('Pizza fromage thon')
queries.append('Pizza cheese tuna')
queries.append('Pomme de terre frite')
queries.append('French fries')
queries.append('Ragoût haricot blanc poulet')
queries.append('Ragoût petit pois poulet')
queries.append('Ragoût pomme de terre poulet')
queries.append('Riz poulet')
queries.append('Rice with chicken')
queries.append('Salade méchouia ')
queries.append('Salade verte')
queries.append('lettuce salad')
queries.append('Sodas')
queries.append('Tagine poulet')
queries.append('Viennoiseries')
queries.append('Yaourt')
queries.append('Yogurt')
queries.append('Mloukhia boeuf')
queries.append('Strew with Corète and beef')
queries.append('Chawarma dinde')
queries.append('Chawarma')
queries.append('Casse-croûte thon')
queries.append('Sandwich with tuna')
queries.append('Purée pomme de terre')
queries.append('Mashed potatoes')
queries.append('chips')
queries.append('pepsi')
queries.append('coca cola')
queries.append('7 up')
queries.append('mirinda')
queries.append('fanta')
queries.append('srite')
queries.append('wings')
queries.append('fasoulia')
queries.append('yakhne')
queries.append('Chocolat')
queries.append('Brick potato cheese tuna')
queries.append('Crepe au chocolat')
queries.append('Omelette')
queries.append('oeuf')
queries.append('beurre')
queries.append('fromage')
queries.append('tomate')
queries.append('concombre')

#non food queries
search = []
#animals
search.append('birds')
search.append('animals')
search.append('insects')
search.append('animals macro shots')
search.append('reptiles')
search.append('fish')
search.append('cat')
search.append('dog')
search.append('bear')
search.append('panda')
search.append('hamster')
search.append('souris')
search.append('moskitoes')
search.append('pets')
search.append('home animals')

#lanscape and nature
search.append('night shots')
search.append('landscape')
search.append('sunset')
search.append('low light landscape')
search.append('night shots landscape')
search.append('beach')
search.append('sand')
search.append('sunrise')
search.append('sky')
search.append('snow')
search.append('wonders')
search.append('river')
search.append('hills')
search.append('oceans')
search.append('sea')
search.append('forest')
search.append('desert')
search.append('space')
search.append('tree')
search.append('mountain')
search.append('flowers')
search.append('cloud')
search.append('sun')
search.append('valley')
search.append('rocks')
search.append('wood')
search.append('plants')
search.append('flowers')
search.append('sun')
search.append('planets')
search.append('stars')
search.append('roads')
search.append('lights')
search.append('light bulbs')
search.append('storms')
search.append('thunder')
search.append('rain')
search.append('sunset')
search.append('sunrise')
#search.append('t shirt')
search.append('tshirt')
search.append('t-shirt')
search.append('socks')
search.append('shoes')
search.append('pants')
search.append('jeans')
search.append('arms')
search.append('hands')
search.append('legs')
search.append('bag')
search.append('school bag')
search.append('jacket')
search.append('keys')
search.append('sofa')
search.append('curtains')
search.append('fingers')

#objects
search.append('cars')
search.append('busses')
search.append('airplanes')
search.append('jet')
search.append('tablets')
search.append('metro')
search.append('train')
search.append('computers')
search.append('technology')
search.append('smart phones')
search.append('iPhone')
search.append('iPad')
search.append('bikes')
search.append('ships')
search.append('television')
search.append('screen')
#locations
search.append('house')
search.append('garden')
search.append('bedroom')
search.append('living room')
search.append('fourniture')
search.append('bathroom')
search.append('door')
search.append('window')
#sports
search.append('music instruments')
search.append('music')
search.append('painting')
search.append('football')
search.append('basketball')
search.append('tennis')
search.append('volley')
search.append('baseball')
search.append('hokey')
search.append('bawling')
search.append('ball')
search.append('casino')
search.append('swimming')
search.append('running')
search.append('walking')
search.append('walk')
search.append('chat')
search.append('text')
search.append('exam')
search.append('score')
search.append('laboratory')
search.append('lab')
search.append('people talk')
search.append('social media')
search.append('tv')
#items
search.append('street')
search.append('libraries')
search.append('university')
search.append('campus')
search.append('stage')
search.append('arena')
search.append('festival')
search.append('highway')
search.append('asphalt')
search.append('walls')
search.append('rooms')
search.append('classes')
search.append('tables')
search.append('chairs')
search.append('labs')
search.append('city')
search.append('village')
search.append('roads')
search.append('subways')
search.append('bag')
search.append('garbage')
search.append('clothes')
search.append('shops')
#people
search.append('people night shot')
search.append('people face')
search.append('people')


queries = list(dict.fromkeys(queries))
search = list(dict.fromkeys(search))

print(len(queries))
print(len(search))
print("done")

# %% [markdown]
# # Functions

# %%
#################################################FUNCTIONS##################################################
# generate all directories
def generateResDirectories(engine, resolution, items, filters):
    directories = []
    for i in range(len(items)):
        for j in range(len(filters)):
            directories.append('%s\\%s\\%s\\%s\\%s' % (IMAGE_FOLDER_PATH, engine, resolution, items[i], filters[j]))
    return directories

#generate a limited number of absolute path for images
def generateLimitedImgDirectories(engine, resolution, items, filters, limit):
    directories = []
    limit_per_class = int(limit / len(items)) + 1
    global_counter = 0
    counter = 0
    for i in range(len(items)):
        counter = 0
        for j in range(len(filters)):
            if(counter >= limit_per_class):
                counter = 0
                break
            else:
                current_directory = IMAGE_FOLDER_PATH + "\\" + engine + "\\" + resolution + "\\" + items[i] + "\\" + filters[j]
                try:    
                    for filename in os.listdir(current_directory):
                        if(counter < limit_per_class):
                            image_path = os.path.join(current_directory, filename)
                            directories.append(image_path)
                            counter = counter + 1
                            global_counter = global_counter + 1
                        else:
                            break
                except:
                    continue
    print("Number of Image Directories Generated from %s with a %s resolution is : %d" % (engine, resolution, global_counter))                    
    return directories

def generateDirectories(engine, items, filters):
    directories = []
    for i in range(len(items)):
        for j in range(len(filters)):
            directories.append('%s\\%s\\%s' % (engine, items[i], filters[j]))
    return directories

def generateGeneralDirectories(engine, items):
    directories = []
    for i in range(len(items)):
        directories.append('%s\\%s' % (engine, items[i]))
    return directories

def showImage(filename):
    im = cv2.imread('%s' % filename)
    im_resized = cv2.resize(im, (480, 360), interpolation=cv2.INTER_LINEAR)
    plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
    plt.show()
    
def generateSpecificDirectories(engine, resolution, item, filters):
    directories = []
    counter = 0
    for j in range(len(filters)):
        current_directory = IMAGE_FOLDER_PATH + "\\" + engine + "\\" + resolution + "\\" + item + "\\" + filters[j]
        for filename in os.listdir(current_directory):
            image_path = os.path.join(current_directory, filename)
            directories.append(image_path)
            counter += 1
            if(counter > 3):
                counter = 0
                break
    print("Number of Images Generated from %s with a %s resolution is : %d" % (engine, resolution, counter))                    
    return directories
    
def showImgSamples(directories):
    for i in range(len(directories)):
        showImage(directories[i])
    
def printImageSamples(engine, resolution, item, filters):
    dir = generateSpecificDirectories(engine, resolution, item, filters)
    showImgSamples(dir)
    
def printFoodQuerySamples(query):
    print("GOOGLE")
    printImageSamples('Google_Food', '256', query, filterNames)
    printImageSamples('Google_Food', '360', query, filterNames)
    printImageSamples('Google_Food', '480', query, filterNamesExtended)
    printImageSamples('Google_Food', '640', query, filterNames)
    printImageSamples('Google_Food', '720', query, filterNamesExtended)
    printImageSamples('Google_Food', 'medium', query, filterNames)
    printImageSamples('Google_Food', '1024', query, filterNamesExtended)
    printImageSamples('Google_Food', '1080', query, filterNamesExtended)
    printImageSamples('Google_Food', 'large', query, filterNames)
    print("BING")
    printImageSamples('Bing_Food', 'small', query, BingfilterNames)
    printImageSamples('Bing_Food', '640', query, BingfilterNames)
    printImageSamples('Bing_Food', '1000', query, BingfilterNames)
    printImageSamples('Bing_Food', 'medium', query, BingfilterNames)
    printImageSamples('Bing_Food', 'large', query, BingfilterNames)
    printImageSamples('Bing_Food', '1280', query, BingfilterNames)
    printImageSamples('Bing_Food', '1920', query, BingfilterNames)

def copyUsableImages(directories, target):
    if not os.path.exists(target):
        os.makedirs(target)
    print("Renaming and Copying %d images..." % (len(directories)))
    for i in range(len(directories)):
        print("Processing %d of %d ..." % (i, len(directories)))
        source = directories[i]
        dst = target + '%d.jpg' % (i)
        os.rename(source, dst)
    print("Done")
    
def CreateNewDatasets(directories, target, temp):
    if not os.path.exists(target):
        os.makedirs(target)
    if not os.path.exists(temp):
        os.makedirs(temp)
    print("Renaming and Copying %d images..." % (len(directories)))
    for i in range(len(directories)):
        print("Processing %d of %d ..." % (i, len(directories)))
        source = directories[i]
        dst = target + '%d.jpg' % (i)
        copy2(source, temp)
        for filename in os.listdir(temp):
            image_path = os.path.join(temp, filename)
            os.rename(image_path, dst)
    print("Done")
    
def generateStatistics(Google_Limit, Bing_Limit):
    print("Using " + IMAGE_FOLDER_PATH + " as Dataset Directory")
    print("Processing Directory " + IMAGE_FOLDER_PATH)

    DatasetDirectories_Food = []
    DatasetDirectories_Non_Food = []

    #list of Google Food Images
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Google_Food', '256', queries, filterNames, Google_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Google_Food', '360', queries, filterNames, Google_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Google_Food', '480', queries, filterNamesExtended, Google_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Google_Food', '640', queries, filterNames, Google_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Google_Food', '720', queries, filterNamesExtended, Google_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Google_Food', 'medium', queries, filterNames, Google_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Google_Food', '1024', queries, filterNamesExtended, Google_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Google_Food', '1080', queries, filterNamesExtended, Google_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Google_Food', 'large', queries, filterNames, Google_Limit))

    #list of Google Non-Food Images
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Google_Non Food', '256', search, filterNames_nf, Google_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Google_Non Food', '360', search, filterNames_nf, Google_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Google_Non Food', '480', search, filterNamesExtended_nf, Google_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Google_Non Food', '640', search, filterNames_nf, Google_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Google_Non Food', '720', search, filterNamesExtended_nf, Google_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Google_Non Food', 'medium', search, filterNames_nf, Google_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Google_Non Food', '1024', search, filterNamesExtended_nf, Google_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Google_Non Food', '1080', search, filterNamesExtended_nf, Google_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Google_Non Food', 'large', search, filterNames_nf, Google_Limit))

    #list of Bing Food Images
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Bing_Food', 'small', queries, BingfilterNames, Bing_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Bing_Food', '640', queries, BingfilterNames, Bing_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Bing_Food', '1000', queries, BingfilterNames, Bing_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Bing_Food', 'medium', queries, BingfilterNames, Bing_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Bing_Food', 'large', queries, BingfilterNames, Bing_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Bing_Food', '1280', queries, BingfilterNames, Bing_Limit))
    DatasetDirectories_Food.append(generateLimitedImgDirectories('Bing_Food', '1920', queries, BingfilterNames, Bing_Limit))

    #list of Bing Non-Food Images
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Bing_Non Food', 'small', search, BingfilterNames_nf, Bing_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Bing_Non Food', '640', search, BingfilterNames_nf, Bing_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Bing_Non Food', '1000', search, BingfilterNames_nf, Bing_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Bing_Non Food', 'medium', search, BingfilterNames_nf, Bing_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Bing_Non Food', 'large', search, BingfilterNames_nf, Bing_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Bing_Non Food', '1280', search, BingfilterNames_nf, Bing_Limit))
    DatasetDirectories_Non_Food.append(generateLimitedImgDirectories('Bing_Non Food', '1920', search, BingfilterNames_nf, Bing_Limit))

    print("directories generated")
    
def generateFullDataset(GL, BL):
    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '256', queries, filterNames, GL), FOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '360', queries, filterNames, GL), FOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '480', queries, filterNamesExtended, GL), FOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '640', queries, filterNames, GL), FOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '720', queries, filterNamesExtended, GL), FOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'medium', queries, filterNames, GL), FOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1024', queries, filterNamesExtended, GL), FOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1080', queries, filterNamesExtended, GL), FOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'large', queries, filterNames, GL), FOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '256', search, filterNames_nf, GL), NOFOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '360', search, filterNames_nf, GL), NOFOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '480', search, filterNamesExtended_nf, GL), NOFOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '640', search, filterNames_nf, GL), NOFOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '720', search, filterNamesExtended_nf, GL), NOFOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'medium', search, filterNames_nf, GL), NOFOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1024', search, filterNamesExtended_nf, GL), NOFOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1080', search, filterNamesExtended_nf, GL), NOFOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'large', search, filterNames_nf, GL), NOFOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'small', queries, BingfilterNames, BL), FOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '640', queries, BingfilterNames, BL), FOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1000', queries, BingfilterNames, BL), FOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'medium', queries, BingfilterNames, BL), FOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'large', queries, BingfilterNames, BL), FOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1280', queries, BingfilterNames, BL), FOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1920', queries, BingfilterNames, BL), FOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'small', search, BingfilterNames_nf, BL), NOFOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '640', search, BingfilterNames_nf, BL), NOFOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1000', search, BingfilterNames_nf, BL), NOFOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'medium', search, BingfilterNames_nf, BL), NOFOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'large', search, BingfilterNames_nf, BL), NOFOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1280', search, BingfilterNames_nf, BL), NOFOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1920', search, BingfilterNames_nf, BL), NOFOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

def generateVeryTinyDataset(GL, BL):
    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '256', queries, filterNames, GL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '360', queries, filterNames, GL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '480', queries, filterNamesExtended, GL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '640', queries, filterNames, GL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '720', queries, filterNamesExtended, GL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'medium', queries, filterNames, GL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1024', queries, filterNamesExtended, GL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1080', queries, filterNamesExtended, GL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'large', queries, filterNames, GL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '256', search, filterNames_nf, GL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '360', search, filterNames_nf, GL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '480', search, filterNamesExtended_nf, GL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '640', search, filterNames_nf, GL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '720', search, filterNamesExtended_nf, GL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'medium', search, filterNames_nf, GL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1024', search, filterNamesExtended_nf, GL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1080', search, filterNamesExtended_nf, GL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'large', search, filterNames_nf, GL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'small', queries, BingfilterNames, BL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '640', queries, BingfilterNames, BL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1000', queries, BingfilterNames, BL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'medium', queries, BingfilterNames, BL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'large', queries, BingfilterNames, BL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1280', queries, BingfilterNames, BL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1920', queries, BingfilterNames, BL), VERY_TINY_FOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'small', search, BingfilterNames_nf, BL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '640', search, BingfilterNames_nf, BL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1000', search, BingfilterNames_nf, BL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'medium', search, BingfilterNames_nf, BL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'large', search, BingfilterNames_nf, BL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1280', search, BingfilterNames_nf, BL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1920', search, BingfilterNames_nf, BL), VERY_TINY_NOFOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)
    
def generateTinyDataset(GL, BL):
    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '256', queries, filterNames, GL), TINY_FOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '360', queries, filterNames, GL), TINY_FOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '480', queries, filterNamesExtended, GL), TINY_FOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '640', queries, filterNames, GL), TINY_FOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '720', queries, filterNamesExtended, GL), TINY_FOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'medium', queries, filterNames, GL), TINY_FOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1024', queries, filterNamesExtended, GL), TINY_FOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1080', queries, filterNamesExtended, GL), TINY_FOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'large', queries, filterNames, GL), TINY_FOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '256', search, filterNames_nf, GL), TINY_NOFOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '360', search, filterNames_nf, GL), TINY_NOFOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '480', search, filterNamesExtended_nf, GL), TINY_NOFOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '640', search, filterNames_nf, GL), TINY_NOFOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '720', search, filterNamesExtended_nf, GL), TINY_NOFOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'medium', search, filterNames_nf, GL), TINY_NOFOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1024', search, filterNamesExtended_nf, GL), TINY_NOFOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1080', search, filterNamesExtended_nf, GL), TINY_NOFOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'large', search, filterNames_nf, GL), TINY_NOFOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'small', queries, BingfilterNames, BL), TINY_FOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '640', queries, BingfilterNames, BL), TINY_FOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1000', queries, BingfilterNames, BL), TINY_FOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'medium', queries, BingfilterNames, BL), TINY_FOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'large', queries, BingfilterNames, BL), TINY_FOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1280', queries, BingfilterNames, BL), TINY_FOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1920', queries, BingfilterNames, BL), TINY_FOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'small', search, BingfilterNames_nf, BL), TINY_NOFOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '640', search, BingfilterNames_nf, BL), TINY_NOFOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1000', search, BingfilterNames_nf, BL), TINY_NOFOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'medium', search, BingfilterNames_nf, BL), TINY_NOFOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'large', search, BingfilterNames_nf, BL), TINY_NOFOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1280', search, BingfilterNames_nf, BL), TINY_NOFOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1920', search, BingfilterNames_nf, BL), TINY_NOFOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

def generateBalancedDataset(GL, BL):
    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '256', queries, filterNames, GL), BALANCED_FOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '360', queries, filterNames, GL), BALANCED_FOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '480', queries, filterNamesExtended, GL), BALANCED_FOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '640', queries, filterNames, GL), BALANCED_FOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '720', queries, filterNamesExtended, GL), BALANCED_FOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'medium', queries, filterNames, GL), BALANCED_FOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1024', queries, filterNamesExtended, GL), BALANCED_FOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1080', queries, filterNamesExtended, GL), BALANCED_FOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'large', queries, filterNames, GL), BALANCED_FOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '256', search, filterNames_nf, GL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '360', search, filterNames_nf, GL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '480', search, filterNamesExtended_nf, GL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '640', search, filterNames_nf, GL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '720', search, filterNamesExtended_nf, GL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'medium', search, filterNames_nf, GL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1024', search, filterNamesExtended_nf, GL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1080', search, filterNamesExtended_nf, GL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'large', search, filterNames_nf, GL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'small', queries, BingfilterNames, BL), BALANCED_FOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '640', queries, BingfilterNames, BL), BALANCED_FOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1000', queries, BingfilterNames, BL), BALANCED_FOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'medium', queries, BingfilterNames, BL), BALANCED_FOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'large', queries, BingfilterNames, BL), BALANCED_FOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1280', queries, BingfilterNames, BL), BALANCED_FOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1920', queries, BingfilterNames, BL), BALANCED_FOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'small', search, BingfilterNames_nf, BL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '640', search, BingfilterNames_nf, BL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1000', search, BingfilterNames_nf, BL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'medium', search, BingfilterNames_nf, BL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'large', search, BingfilterNames_nf, BL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1280', search, BingfilterNames_nf, BL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1920', search, BingfilterNames_nf, BL), BALANCED_NOFOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

def generateLargeDataset(GL, BL):
    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '256', queries, filterNames, GL), LARGE_FOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '360', queries, filterNames, GL), LARGE_FOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '480', queries, filterNamesExtended, GL), LARGE_FOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '640', queries, filterNames, GL), LARGE_FOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '720', queries, filterNamesExtended, GL), LARGE_FOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'medium', queries, filterNames, GL), LARGE_FOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1024', queries, filterNamesExtended, GL), LARGE_FOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1080', queries, filterNamesExtended, GL), LARGE_FOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'large', queries, filterNames, GL), LARGE_FOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '256', search, filterNames_nf, GL), LARGE_NOFOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '360', search, filterNames_nf, GL), LARGE_NOFOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '480', search, filterNamesExtended_nf, GL), LARGE_NOFOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '640', search, filterNames_nf, GL), LARGE_NOFOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '720', search, filterNamesExtended_nf, GL), LARGE_NOFOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'medium', search, filterNames_nf, GL), LARGE_NOFOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1024', search, filterNamesExtended_nf, GL), LARGE_NOFOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1080', search, filterNamesExtended_nf, GL), LARGE_NOFOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'large', search, filterNames_nf, GL), LARGE_NOFOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'small', queries, BingfilterNames, BL), LARGE_FOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '640', queries, BingfilterNames, BL), LARGE_FOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1000', queries, BingfilterNames, BL), LARGE_FOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'medium', queries, BingfilterNames, BL), LARGE_FOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'large', queries, BingfilterNames, BL), LARGE_FOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1280', queries, BingfilterNames, BL), LARGE_FOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1920', queries, BingfilterNames, BL), LARGE_FOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'small', search, BingfilterNames_nf, BL), LARGE_NOFOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '640', search, BingfilterNames_nf, BL), LARGE_NOFOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1000', search, BingfilterNames_nf, BL), LARGE_NOFOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'medium', search, BingfilterNames_nf, BL), LARGE_NOFOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'large', search, BingfilterNames_nf, BL), LARGE_NOFOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1280', search, BingfilterNames_nf, BL), LARGE_NOFOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    #CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1920', search, BingfilterNames_nf, BL), LARGE_NOFOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

def generateSmallDataset(GL, BL):
    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '256', queries, filterNames, GL), SMALL_FOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '360', queries, filterNames, GL), SMALL_FOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '480', queries, filterNamesExtended, GL), SMALL_FOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '640', queries, filterNames, GL), SMALL_FOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '720', queries, filterNamesExtended, GL), SMALL_FOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'medium', queries, filterNames, GL), SMALL_FOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1024', queries, filterNamesExtended, GL), SMALL_FOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', '1080', queries, filterNamesExtended, GL), SMALL_FOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Food', 'large', queries, filterNames, GL), SMALL_FOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '256', search, filterNames_nf, GL), SMALL_NOFOOD_OUTPUT_DIRECTORY_G256p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '360', search, filterNames_nf, GL), SMALL_NOFOOD_OUTPUT_DIRECTORY_G360p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '480', search, filterNamesExtended_nf, GL), SMALL_NOFOOD_OUTPUT_DIRECTORY_G480p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '640', search, filterNames_nf, GL), SMALL_NOFOOD_OUTPUT_DIRECTORY_G640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '720', search, filterNamesExtended_nf, GL), SMALL_NOFOOD_OUTPUT_DIRECTORY_G720p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'medium', search, filterNames_nf, GL), SMALL_NOFOOD_OUTPUT_DIRECTORY_GMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1024', search, filterNamesExtended_nf, GL), SMALL_NOFOOD_OUTPUT_DIRECTORY_G1024p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', '1080', search, filterNamesExtended_nf, GL), SMALL_NOFOOD_OUTPUT_DIRECTORY_G1080p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Google_Non Food', 'large', search, filterNames_nf, GL), SMALL_NOFOOD_OUTPUT_DIRECTORY_GLarge, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'small', queries, BingfilterNames, BL), SMALL_FOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '640', queries, BingfilterNames, BL), SMALL_FOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1000', queries, BingfilterNames, BL), SMALL_FOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'medium', queries, BingfilterNames, BL), SMALL_FOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', 'large', queries, BingfilterNames, BL), SMALL_FOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1280', queries, BingfilterNames, BL), SMALL_FOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Food', '1920', queries, BingfilterNames, BL), SMALL_FOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

    #restructure dataset path and convert all images to .jpg extension
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'small', search, BingfilterNames_nf, BL), SMALL_NOFOOD_OUTPUT_DIRECTORY_BSmall, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '640', search, BingfilterNames_nf, BL), SMALL_NOFOOD_OUTPUT_DIRECTORY_B640p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1000', search, BingfilterNames_nf, BL), SMALL_NOFOOD_OUTPUT_DIRECTORY_B1000p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'medium', search, BingfilterNames_nf, BL), SMALL_NOFOOD_OUTPUT_DIRECTORY_BMedium, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', 'large', search, BingfilterNames_nf, BL), SMALL_NOFOOD_OUTPUT_DIRECTORY_BLarge, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1280', search, BingfilterNames_nf, BL), SMALL_NOFOOD_OUTPUT_DIRECTORY_B1280p, IMAGE_TEMP_PATH)
    CreateNewDatasets(generateLimitedImgDirectories('Bing_Non Food', '1920', search, BingfilterNames_nf, BL), SMALL_NOFOOD_OUTPUT_DIRECTORY_B1920p, IMAGE_TEMP_PATH)

# %% [markdown]
# # Generating Dataset Statistics

# %%
generateStatistics(Google_Limit, Bing_Limit)

# %% [markdown]
# # Generate The Complete Scale-Size Dataset (Limit = None)

# %%
generateFullDataset(60000, 5000)

# %% [markdown]
# # Generate a Very Tiny Dataset (Limit  = 1000)

# %%
generateVeryTinyDataset(Google_Limit_Very_Tiny, Bing_Limit_Very_Tiny)

# %% [markdown]
# # Generate A Tiny Dataset (Limit = 2000)

# %%
generateTinyDataset(Google_Limit_Tiny, Bing_Limit_Tiny)

# %% [markdown]
# # Generate A Small Dataset (Limit = 5000)

# %%
generateSmallDataset(Google_Limit_Small, Bing_Limit_Small)

# %% [markdown]
# # Generate A Balanced Dataset (Limit = 10,000)

# %%
generateBalancedDataset(Google_Limit_Balanced, Bing_Limit_Balanced)

# %% [markdown]
# # Generate A Large Dataset (Limit = 20,000)

# %%
generateLargeDataset(Google_Limit_Large, Bing_Limit_Large)
